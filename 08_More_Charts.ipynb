# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = np.random.randint(1,50,100) # del 1 al 50, 100 ejemplos

# %% [markdown]
# ## Analizar distribución y frecuencia. Histograma

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data,bins=50) # por defualt el histograma muestra 10 bins
plt.show()

# %%
plt.hist(data,bins=50,width=5)
plt.show()

# %%
plt.hist(data,bins=10,histtype='step')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data,vert=False)
plt.show()

# %%
plt.boxplot(data,vert=False,patch_artist=True)
plt.show()

# %%
plt.boxplot(data,vert=False,patch_artist=True,notch=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data,vert=False,patch_artist=True,notch=True)
plt.show()

# %%
data = np.append(data,200)
plt.boxplot(data,vert=False,patch_artist=True,notch=True,showfliers=False)
plt.show()

# %% [markdown]
# ## Grafico de dispersión. Scatter

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
area = (30 * x ) ** 2
colors = np.random.rand(N)

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.scatter(x,y,s=area)
plt.show()

# %%
plt.scatter(x,y,s=area,c=colors)
plt.show()

# %%
plt.scatter(x,y,s=area,c=colors,marker='p')
plt.show()

# %%
plt.scatter(x,y,s=area,c=colors,marker='p',alpha=0.5)
plt.show()
