# %% [markdown]
# # Seaborn

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ![sns_01.png](attachment:sns_01.png)

# %% [markdown]
# ## Ventajas
# * velocidad
# * poco código
# * personalizable

# %% [markdown]
# ![sns_estructura_basica.png](attachment:sns_estructura_basica.png)

# %% [markdown]
# ![sns_chart_types.png](attachment:sns_chart_types.png)
